# %% [markdown]
# # Manipulação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
os.chdir("C:/Users/Usuario/Documents/Faculdade/2023.1/TCC/Artefatos do TCC")

# %%
df = pd.read_csv('tweetsDe2012a2023Final.csv', )

# %%
#verificar a quantidade de usuários unicos que constam na base 
print(df.username.nunique())

#foram encontrados 651.080 de usuários unicos
# Out:
# 651080

# %%
#tabela com média tweets por usuário | exemplo no artigo das eleições eua
#tabela com termos mais populares

# %% [markdown]
# Criando base de Tweets de 2012

# %%
#apagando tweets duplicados
ind = df[df['filtered_text'].str.contains('ATUAL POLITICA DROGAS BRASIL FRACASSO ASSINE PETICAO NOVA SOLUCAO DROGAS AVAAZ')].index
df.drop(ind, inplace=True)
df.to_csv( "tweetsDe2012a2023Final.csv", index=False, encoding='utf-8-sig')

# %%
# Filter data between two dates
df2012 = df.loc[(df['date'] >= '2012-01-01')
                     & (df['date'] <= '2012-12-31')]

# %%
# Filter data between two dates
df2013 = df.loc[(df['date'] >= '2013-01-01')
                     & (df['date'] <= '2013-12-31')]

# %%
# Filter data between two dates
df2014 = df.loc[(df['date'] >= '2014-01-01')
                     & (df['date'] <= '2014-12-31')]

# %%
# Filter data between two dates
df2015 = df.loc[(df['date'] >= '2015-01-01')
                     & (df['date'] <= '2015-12-31')]

# %%
# Filter data between two dates
df2016 = df.loc[(df['date'] >= '2016-01-01')
                     & (df['date'] <= '2016-12-31')]

# %%
# Filter data between two dates
df2017 = df.loc[(df['date'] >= '2017-01-01')
                     & (df['date'] <= '2017-12-31')]

# %%
# Filter data between two dates
df2018 = df.loc[(df['date'] >= '2018-01-01')
                     & (df['date'] <= '2018-12-31')]

# %%
# Filter data between two dates
df2019 = df.loc[(df['date'] >= '2019-01-01')
                     & (df['date'] <= '2019-12-31')]

# %%
# Filter data between two dates
df2020 = df.loc[(df['date'] >= '2020-01-01')
                     & (df['date'] <= '2020-12-31')]

# %%
# Filter data between two dates
df2021 = df.loc[(df['date'] >= '2021-01-01')
                     & (df['date'] <= '2021-12-31')]

# %%
# Filter data between two dates
df2022 = df.loc[(df['date'] >= '2022-01-01')
                     & (df['date'] <= '2022-12-31')]

# %%
# Filter data between two dates
df2023 = df.loc[(df['date'] >= '2023-01-01')
                     & (df['date'] <= '2023-12-31')]

# %%
# filtro generico
df2 = df.loc[(df2022['date'] >= '2022-10-03')
                     & (df['date'] <= '2022-10-04')]

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, url, username, filtered_text, tokens, bigramas, trigramas, hour, occurrences]
# Index: []

# %%
#exportar para csv
df.to_csv( "soTweets.csv", index=False, encoding='utf-8-sig')

# %%
#apaga colunas desnecessárias
df = df.drop(columns=['Unnamed: 0','date',	'url',	'username',	'tokens','bigramas','trigramas', 'hour','occurrences'])

# %% [markdown]
# # Palavras mais repetidas

# %%
pd.Series(' '.join(df2['bigramas']).split()).value_counts()[:10]
# Out:
# 'POLITICA'),     18913
# ('POLITICA',     18913
# ('BRASIL',       17082
# 'BRASIL'),       17082
# 'CRISE'),         3053
# ('CRISE',         3053
# 'BRASIL')]        1828
# [('BRASIL',       1794
# [('POLITICA',     1654
# 'SITUACAO'),      1323
# dtype: int64

# %% [markdown]
# # Nuvem de palavras

# %%
#palavras = " ".join(df.tokens)
stopwords2014 = "POLITICA", "BRASIL", "VVK0BMOXWU", "VVK0BMOXWU", "FOLHA", "PSICANALISE"

# %%
from wordcloud import WordCloud
import nltk
import matplotlib.pyplot as plt
stopwords = "POLITICA", "BRASIL","FOLHA", "CORREIO BRAZILIENSE","CORREIO", "BRAZILIENSE","BRASIL247","VVK0BMOXWU","VVK0BMOXWU", ""
palavras = " ".join(df2.filtered_text) #tranforta em um uma string enorme

text = palavras
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'white',
    max_words= 50,
    min_word_length= 4,
    stopwords=stopwords).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Parte aleatória da base de dados

# %%
pd.options.display.max_colwidth = None
df2012[['date', 'filtered_text']].sample(10)
# Out:
#                date  \
# 828878   2012-03-06
# 97353    2012-04-17
# 1620363  2012-12-10
# 546533   2012-11-22
# 981293   2012-05-24
# 1150569  2012-07-21
# 253256   2012-06-03
# 693837   2012-01-16
# 96427    2012-04-24
# 546964   2012-11-18
#
#                                                                                                        filtered_text
# 828878                                           SEDE GLORIOSO PCDOB DISCUTIR COMEMORACOES ANOS VIDA POLITICA BRASIL
# 97353       DEPDURVALANGELO ENTRE PERFIS INFLUENTES TWITTER POLITICA BRASIL PRESIDENTA DILMA LEONARD //T.CO/M5PVESZJ
# 1620363          ESTRATEGIA DIGITAL POLITICA BRASIL RIDICULA GAUCHO TRABALHOU CAMPANHAS BARACK OBAMA //T.CO/HUJJ54WR
# 546533   ARYKARA JORNALISTA MORTO TIROS CAMPO GRANDE POLITICA //T.CO/FQOVUKWX CENSURAR BALA BRASIL BATE RECORD NISSO
# 981293      JOSESERRA_ PROPAGANDA POLITICA MOSTRE TODAS SUAS OBRAS SAMPA.TEMOS TANTO ORGULHO DELASMOSTRE BRASIL AQUI
# ...

# %% [markdown]
# # Graficos

# %%
df2012 = df2012.groupby(['date']).sum(['occurrence'])
df2012.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2012 = df2012.drop(columns=['Unnamed: 0'])

# %%
df2013 = df2013.groupby(['date']).sum(['occurrence'])
df2013.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2013 = df2013.drop(columns=['Unnamed: 0'])

# %%
df2014 = df2014.groupby(['date']).sum(['occurrence'])
df2014.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2014 = df2014.drop(columns=['Unnamed: 0'])

# %%
df2015 = df2015.groupby(['date']).sum(['occurrence'])
df2015.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2015 = df2015.drop(columns=['Unnamed: 0'])

# %%
df2016 = df2016.groupby(['date']).sum(['occurrence'])
df2016.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2016 = df2016.drop(columns=['Unnamed: 0'])

# %%
df2017 = df2017.groupby(['date']).sum(['occurrence'])
df2017.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2017 = df2017.drop(columns=['Unnamed: 0'])

# %%
df2018 = df2018.groupby(['date']).sum(['occurrence'])
df2018.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2018 = df2018.drop(columns=['Unnamed: 0'])

# %%
df2019 = df2019.groupby(['date']).sum(['occurrence'])
df2019.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
#df2019 = df2019.drop(columns=['Unnamed: 0'])

# %%
df2020 = df2020.groupby(['date']).sum(['occurrence'])
df2020.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2020 = df2020.drop(columns=['Unnamed: 0'])

# %%
df2021 = df2021.groupby(['date']).sum(['occurrence'])
df2021.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2021 = df2021.drop(columns=['Unnamed: 0'])

# %%
df2022 = df2022.groupby(['date']).sum(['occurrence'])
df2022.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2022 = df2022.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11904/1707384591.py in <module>
# ----> 1 df2022 = df2022.groupby(['date']).sum(['occurrence'])
#       2 df2022.reset_index(level=0, inplace=True)
#       3 pd.options.display.max_rows = 370
#       4 df2022 = df2022.drop(columns=['Unnamed: 0'])
#
# AttributeError: 'numpy.int64' object has no attribute 'groupby'

# %%
df2023 = df2023.groupby(['date']).sum(['occurrence'])
df2023.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370
df2023 = df2023.drop(columns=['Unnamed: 0'])

# %%
#ordenando pela data do tweet
df2012.sort_values(by='date')
df2013.sort_values(by='date') 
df2014.sort_values(by='date') 
df2015.sort_values(by='date') 
df2016.sort_values(by='date') 
df2017.sort_values(by='date') 
df2016.sort_values(by='date') 
df2018.sort_values(by='date') 
df2019.sort_values(by='date') 
df2020.sort_values(by='date') 
df2021.sort_values(by='date') 
df2022.sort_values(by='date') 
df2023.sort_values(by='date')

# %%
df2= pd.concat([df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021, df2022, df2023], ignore_index=True)

# %%
df2012 = df2012.drop(columns=['mean30days'])

# %%
#calculado a media movel com janela de de 7 dias
df2012['mean7days'] = df2012.occurrences.rolling(7).mean()

# %%
#plotagem geral
import seaborn as sns 
plt.figure( figsize = ( 20, 10)) 
sns.lineplot( x = 'date', 
             y = 'occurrences', 
             data = df2023, 
             label = 'Tweets') 
sns.lineplot( x = 'date', 
             y = 'mean7days', 
             data = df2023, 
             label = 'Média móvel com janela de 7 dias') 
  
plt.xlabel('Anos') 
pos = [ '2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01','2023-01-01'] 
  
lab = [ '2012', '2013', '2014', '2015', '2016', '2017',  
       '2018', '2019', '2020', '2021', '2022', '2023'] 
  
plt.xticks( pos, lab) 
  
plt.ylabel('Quantidade de Tweets')
# Out:
#   File "C:\Users\Usuario\AppData\Local\Temp/ipykernel_6216/2395136064.py", line 17
#     '2023', '2023', '2023 '2023', '2023', '2023']
#                            ^
# SyntaxError: invalid syntax

# %%
df2012

# %%
#plotagem por ano
import seaborn as sns 
plt.figure( figsize = ( 20, 10)) 
sns.lineplot( x = 'date', 
             y = 'occurrences', 
             data = df2012, 
             label = 'Tweets') 
sns.lineplot( x = 'date', 
             y = 'mean7days', 
             data = df2012, 
             label = 'Média móvel com janela de 7 dias') 
  
plt.xlabel('Meses') 
pos = [ '2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01', '2012-12-01'] 
  
lab = [ 'jan', 'fev', 'mar', 'abri', 'mai', 'jun',  
       'jul', 'ago', 'set', 'out', 'nov', 'dez'] 
  
plt.xticks( pos, lab) 
  
plt.ylabel('Quantidade de Tweets')
# Out:
# Text(0, 0.5, 'Quantidade de Tweets')

# %%
# filtro generico
df2 = df.loc[(df2022['date'] >= '2022-10-01')
                     & (df['date'] <= '2022-10-07')]

# %%
df2 = df2.groupby(['date']).sum(['occurrence'])
df2.reset_index(level=0, inplace=True)
pd.options.display.max_rows = 370

# %%
df2
# Out:
#          date  Unnamed: 0  occurrences
# 0  2022-10-01   117079314         1916
# 1  2022-10-02   180767143         3086
# 2  2022-10-03   368785447         6890
# 3  2022-10-04   175338099         3638
# 4  2022-10-05   129045976         2874
# 5  2022-10-06    86346118         2035
# 6  2022-10-07    63962891         1575

# %%
#plotagem por semana

import seaborn as sns 
plt.figure( figsize = ( 20, 10)) 
sns.lineplot( x = 'date', 
             y = 'occurrences', 
             data = df2, 
             label = 'Tweets') 

  
plt.xlabel('Dias') 
pos = [ '2022-10-01', '2022-10-02', '2022-10-03', '2022-10-04', '2022-10-05', '2022-10-06', '2022-10-07', '2022-10-08'] 
  

  
plt.xticks( pos) 
  
plt.ylabel('Quantidade de Tweets')
# Out:
# Text(0, 0.5, 'Quantidade de Tweets')

# %% [markdown]
# # GRAFICO QUANTIDADE GERAL POR ANO

# %%
df2012 = df2012['occurrences'].sum()
df2013 = df2013['occurrences'].sum()
df2014 = df2014['occurrences'].sum()
df2015 = df2015['occurrences'].sum()
df2016 = df2016['occurrences'].sum()
df2017 = df2017['occurrences'].sum()
df2018 = df2018['occurrences'].sum()
df2019 = df2019['occurrences'].sum()
df2020 = df2020['occurrences'].sum()
df2021 = df2021['occurrences'].sum()
df2022 = df2022['occurrences'].sum()
df2023 = df2023['occurrences'].sum()

# %%
dfAno = pd.DataFrame({'Ano': ['2012', '2013', '2014', '2015', '2016', '2017', '2018','2019','2020','2021','2022'], 'Quantidade de Tweets': [df2012, df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021, df2022]})

# %%
#plotagem

import seaborn as sns 
plt.figure( figsize = ( 20, 10)) 
sns.lineplot( x = 'Ano',
             y = dfAno['Quantidade de Tweets'], 
             data = dfAno,
             label = 'Tweets') 

  
plt.xlabel('Anos') 
pos = [ '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'] 
  

  
plt.xticks( pos) 
  
plt.ylabel('Quantidade de Tweets')
# Out:
# Text(0, 0.5, 'Quantidade de Tweets')
